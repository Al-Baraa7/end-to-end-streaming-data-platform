# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
        .master("spark://spark-master:7077") \
        .appName("silver") \
        .config("spark.sql.legacy.parquet.nanosAsLong", "true") \
        .config("spark.sql.parquet.enableVectorizedReader", "false") \
        .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/05 22:34:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
P = "file:///data/end-to-end-streaming-data-platform/bronze/postgres/ingestion_date=2026-06-05-Jun/users.parquet"
df = spark.read.parquet(P)

# %%
df.show(5)
# Out:
# +--------------------+--------------------+-------+--------------+-------------------+-------------------+
# |             user_id|               email|country|account_status|         created_at|         last_login|
# +--------------------+--------------------+-------+--------------+-------------------+-------------------+
# |55a042c8-70fb-48e...| jesse86@example.net|    MAR|       deleted|1755783833681172000|               NULL|
# |47b4d3ca-7832-439...|taylorrenee@examp...|    KSA|        active|1743867197681172000|1745940797681172000|
# |73298054-91af-41a...|clarkchristina@ex...|    KWT|        active|1767719522681172000|1768237922681172000|
# |792c5481-f58b-491...|emilywilson@examp...|    KSA|     suspended|1766438564681172000|1767129764681172000|
# |2b2a2ffe-e8a5-49d...|samantha83@exampl...|    KWT|     suspended|1765232134681172000|1765404934681172000|
# +--------------------+--------------------+-------+--------------+-------------------+-------------------+
# only showing top 5 rows

# %%
df.show(10)
# Out:
# +--------------------+--------------------+-------+--------------+-------------------+-------------------+
# |             user_id|               email|country|account_status|         created_at|         last_login|
# +--------------------+--------------------+-------+--------------+-------------------+-------------------+
# |55a042c8-70fb-48e...| jesse86@example.net|    MAR|       deleted|1755783833681172000|               NULL|
# |47b4d3ca-7832-439...|taylorrenee@examp...|    KSA|        active|1743867197681172000|1745940797681172000|
# |73298054-91af-41a...|clarkchristina@ex...|    KWT|        active|1767719522681172000|1768237922681172000|
# |792c5481-f58b-491...|emilywilson@examp...|    KSA|     suspended|1766438564681172000|1767129764681172000|
# |2b2a2ffe-e8a5-49d...|samantha83@exampl...|    KWT|     suspended|1765232134681172000|1765404934681172000|
# |75259834-535a-453...|    tcox@example.com|    UAE|        active|1742381833681172000|1743850633681172000|
# |f5ee2a5c-e397-44c...|xandrews@example.net|    EGY|       deleted|1754956811681172000|               NULL|
# |c40bea3a-a266-4ca...|brockheather@exam...|    JOR|       deleted|1771969929681172000|               NULL|
# |aa824cfa-b00d-4bc...|medinabruce@examp...|    KSA|        active|1755433644683185000|1758025644683185000|
# |e4a3ca81-7843-4c3...| wendy47@example.com|    EGY|        active|1768459431683185000|1770101031683185000|
# +--------------------+--------------------+-------+--------------+-------------------+-------------------+
# only showing top 10 rows
